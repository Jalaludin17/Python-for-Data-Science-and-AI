# %%
class Node:
  def __init__(self,value):
    self.data = value
    self.next = None

n1 = Node(1)
n2 = Node(2)
n3 = Node(3)
n4 = Node(4)

n1.next = n2
n2.next = n3
n3.next = n4

corr=n1
while corr!=None:
  print(corr.data, end=' -> ')
  corr=corr.next
# Out:
# 1 -> 2 -> 3 -> 4 ->

# %%
class Node:
  def __init__(self,value):
    self.data = value
    self.next = None

# %%
class LinkedList:

  #constructor
  def __init__(self):
    # Empty Linked List
    self.head = None
    # no of nodes in the LL
    self.n = 0

  #len function
  def __len__(self):
    return self.n

  #insert function
  def insert_head(self,value):

    # new node
    new_node = Node(value)

    # create connection
    new_node.next = self.head

    # reassign head
    self.head = new_node

    # increment n
    self.n = self.n + 1

  #print function
  def __str__(self):

    curr = self.head

    result = ''

    while curr != None:
      result = result + str(curr.data) + '->'
      curr = curr.next

    return result[:-2]

  #append
  def append(self,value):

    new_node = Node(value)

    if self.head == None:
      # empty
      self.head = new_node
      self.n = self.n + 1
      return

    curr = self.head

    while curr.next != None:
      curr = curr.next

    # you are at the last node
    curr.next = new_node
    self.n = self.n + 1

  #insert after any element
  def insert_after(self,after,value):

    new_node = Node(value)

    curr = self.head

    while curr != None:
      if curr.data == after:
        break
      curr = curr.next

    if curr != None:
      new_node.next = curr.next
      curr.next = new_node
      self.n = self.n + 1
    else:
      return 'Item not found'

  #delete all elements
  def clear(self):
    self.head = None
    self.n = 0

 #delete items
  def delete_head(self):

    if self.head == None:
      # empty
      return 'Empty LL'

    self.head = self.head.next
    self.n = self.n - 1

  #pop
  def pop(self):

    if self.head == None:
      # empty
      return 'Empty LL'

    curr = self.head

    # kya linked list me 1 item hai?
    if curr.next == None:
      # head hi hoga(delete from head)
      return self.delete_head()


    while curr.next.next != None:
      curr = curr.next

    # curr -> 2nd last node
    curr.next = None
    self.n = self.n - 1

  #remove
  def remove(self,value):

    if self.head == None:
      return 'Empty LL'

    if self.head.data == value:
      # you want to remove the head node
      return self.delete_head()

    curr = self.head

    while curr.next != None:
      if curr.next.data == value:
        break
      curr = curr.next

    # 2 cases item mil gaya
    # item nai mila
    if curr.next == None:
      # item nai mila
      return 'Not Found'
    else:
      curr.next = curr.next.next
      self.n = self.n - 1

  #search
  def search(self,item):

    curr = self.head
    pos = 0

    while curr != None:
      if curr.data == item:
        return pos
      curr = curr.next
      pos = pos + 1

    return 'Not Found'

  #indexing
  def __getitem__(self,index):

    curr = self.head
    pos = 0

    while curr != None:
      if pos == index:
        return curr.data
      curr = curr.next
      pos = pos + 1

    return 'IndexError'

# %%
l1=LinkedList()

# %%
l1.append(2)
l1.append(3)
l1.append(4)
l1.append(5)

# %%
print(l1)
# Out:
# 2->3->4->5

# %%
len(l1)
# Out:
# 4

# %%
l1.insert_head(1)
print(l1)
# Out:
# 1->2->3->4->5

# %%
l1.insert_after(4,6)
print(l1)
# Out:
# 1->2->3->4->6->5

# %%
l1.delete_head()
print(l1)
# Out:
# 2->3->4->6->5

# %%
l1.pop()
print(l1)
# Out:
# 2->3->4

# %%
l1.__getitem__(2)
# Out:
# 4

# %%
l1.search(3)
# Out:
# 1

# %% [markdown]
# ###**Problems on linkedlist**

# %% [markdown]
# ### problem no 1

# %%
#what will be the output of the following program
n1=Node(1)
n2=Node(2)
n3=Node(3)
n4=Node(4)
n5=Node(5)
n1.next=n2
n2.next=n3
n3.next=n4
n4.next=n5

corr=n1
while corr!=None:
  print(corr.data, end=" -> ")
  corr=corr.next
# Out:
# 1 -> 2 -> 3 -> 4 -> 5 ->

# %%
def fun(head):
  if (head==None):
    return
  if head.next.next!=None:
    print(head.data, "", end='')
    fun(head.next)
  print(head.data, " ", end='')

# %%
print(n1.data, " ", end='')
# Out:
# 1

# %%
fun(n1)
# Out:
# 1 2 3 4  3  2  1

# %% [markdown]
# ### Problem no 2

# %%
class Node:
  def __init__(self, value):
    self.data = value
    self.next = None

def print_list(head):
  corr = head
  while corr is not None:
    print(corr.data, end=" -> ")
    corr = corr.next
  print("None")

def replace_max(head, new_value):
  if head is None:
    return

  # Find max value
  corr = head
  max_value = head.data
  while corr is not None:
    if corr.data > max_value:
      max_value = corr.data
    corr = corr.next

  # Replace all max values
  curr = head
  while curr is not None:
    if curr.data == max_value:
      curr.data = new_value   # ✅ correct variable here
    curr = curr.next

# Create linked list: 1 -> 2 -> 3 -> 4 -> 5
n1 = Node(1)
n2 = Node(2)
n3 = Node(3)
n4 = Node(4)
n5 = Node(5)
n1.next = n2
n2.next = n3
n3.next = n4
n4.next = n5

print("Original list:")
print_list(n1)

replace_max(n1, 99)

print("After replacing max with 99:")
print_list(n1)
# Out:
# Original list:
# 1 -> 2 -> 3 -> 4 -> 5 -> None
# After replacing max with 99:
# 1 -> 2 -> 3 -> 4 -> 99 -> None

# %% [markdown]
# ### Problem no 3

# %%
#sum all odd index elements in the linked list
def sum_odd_num(head):
  corr=head
  counter=0
  result=0

  while corr!=None:
    if counter%2 !=0:
      result=result+corr.data
    corr=corr.next
    counter=counter+1
  print(result)

sum_odd_num(n1)
# Out:
# 6

# %% [markdown]
# ###Problem no 04

# %%
#reverse the integer contaiing linked list
def reverse(head): # None -> 1-> 2-> 3 -> 4 -> None
  corr_node=head #it got 1
  prev_node=None
  while corr_node!=None:        #loop cycle one
    next_node=corr_node.next    #next_node=2
    corr_node.next=prev_node    #corr.next=None
    prev_node=corr_node         #prev_node=1
    corr_node=next_node         #corr_node=2
  return prev_node

# %%
reversed_list=reverse(n1)
print_list(reversed_list)
# Out:
# 99 -> 4 -> 3 -> 2 -> 1 -> None

# %% [markdown]
# ### Problem no 03

# %%
#linked list with characters, convert it into proper sentence
#rule 1 : replace all /,\, with single space
#rule 2 : replace double " or / with single space and convert next character into upper case
